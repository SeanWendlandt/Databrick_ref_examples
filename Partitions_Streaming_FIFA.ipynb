# %%
# Sean Wendlandt
# lab 8 5/18/23

from pyspark.sql.types import StructType, StructField, LongType, StringType, TimestampType
import pyspark.sql.functions as f

# Streaming data setup 
fifaSchema = StructType( \
                        [StructField('ID', LongType(), True), \
                         StructField('lang', StringType(), True), \
                         StructField('Date', TimestampType(), True), \
                         StructField('Source', StringType(), True), \
                         StructField('len', LongType(), True), \
                         StructField('Orig_Tweet', StringType(), True), \
                         StructField('Tweet', StringType(), True), \
                         StructField('Likes', LongType(), True), \
                         StructField('RTs', LongType(), True), \
                         StructField('Hashtags', StringType(), True), \
                         StructField('UserMentionNames', StringType(), True), \
                         StructField('UserMentionID', StringType(), True), \
                         StructField('Name', StringType(), True), \
                         StructField('Place', StringType(), True), \
                         StructField('Followers', LongType(), True), \
                         StructField('Friends', LongType(), True), \
                        ])

# %%
# Load in dataset /FileStore/tables/FIFA__1_.csv
fifa = spark.read.format("csv").option("header", True).schema(fifaSchema).option("ignoreLeadingWhiteSpace", True).option("mode","dropMalformed").load("dbfs:///FileStore/tables/FIFA__1_.csv")

# %%
fifa.show()

#put it into memory as a table so we can do sql on it later
fifa.createOrReplaceTempView("fifa")
# Out:
# +-------------------+----+-------------------+-------------------+---+--------------------+--------------------+-----+----+--------------------+--------------------+--------------------+--------------------+--------------------+---------+-------+
# |                 ID|lang|               Date|             Source|len|          Orig_Tweet|               Tweet|Likes| RTs|            Hashtags|    UserMentionNames|       UserMentionID|                Name|               Place|Followers|Friends|
# +-------------------+----+-------------------+-------------------+---+--------------------+--------------------+-----+----+--------------------+--------------------+--------------------+--------------------+--------------------+---------+-------+
# |1013597056219295744|  en|2018-07-02 01:35:44|Twitter for Android|139|RT @FCBarcelona: ...|scores the winnin...|    0|1031|            WorldCup|FC Barcelona,Ivan...|FCBarcelona,ivanr...|        Febri Aditya|               Bogor|      667|    686|
# |1013597047482544130|  en|2018-07-02 01:35:42|Twitter for Android|107|RT @javierfernand...|Tonight we have b...|    0| 488|            worldcup|Javier Fernandez,...|javierfernandez,E...|                  ??|                null|       65|     67|
# |1013597036090818560|  en|2018-07-02 01:35:39|Twitter for Android|135|RT @SiClancy: I k...|know it been an a...|    0|3817|            worldcup|        Simon Clancy|            SiClancy|                Goku|           Barcelona|      105|     51|
# |1013597035679739904|  en|2018-07-02 01:35:39| Twitter for iPhone|139|RT @valpan026: @e...|by our happy viru...|    0| 107|           POWER,EXO|Shiqi,Eunice,Rach...|valpan026,euniceh...|             ELyXiOn|                null|       12|     88|
# |1013597035629555712|  en|2018-07-02 01:35:39|   Twitter for iPad|166|Get the best in s...|Get the best in s...|    0|   0|sportstalk,sports...|                null|                null|                 JSA|                null|     1978|   4288|
# |1013597035407298560|  en|2018-07-02 01:35:39|   Twitter for iPad|140|RT @IanStaffs: Ju...|Just worked out t...|    0|   7|                null|        Ian Stafford|           IanStaffs|     SKS Media India|       Mumbai, India|     2147|   2403|
# |1013597029623189504|  en|2018-07-02 01:35:38|Twitter for Android| 88|RT @dw_sports: 2 ...|PENALTY SHOOTOUTS...|    0|  17|     CRODEN,WorldCup|           DW Sports|           dw_sports|              miikii|            Thailand|      187|    188|
# |1013597022992195585|  en|2018-07-02 01:35:36|   Twitter for iPad|120|RT @IanStaffs: Wo...|Wonder what the o...|    0|   4|            WorldCup|        Ian Stafford|           IanStaffs|     SKS Media India|       Mumbai, India|     2147|   2403|
# |1013597015375339520|  en|2018-07-02 01:35:34| Twitter for iPhone|125|RT @LeJuan__James...|Lebron news is co...|    0|   3|            WorldCup|        LeJuan James|       LeJuan__James|          DD Benitez|The Ohio State Un...|      171|    403|
# |1013597014481760256|  en|2018-07-02 01:35:34| Twitter for iPhone|140|RT @eunicehuili: ...|Highly anticipati...|    0| 105|           POWER,EXO|Eunice,Rachel Wen...|eunicehuili,Rache...|             ELyXiOn|                null|       12|     88|
# |1013597009159311362|  en|2018-07-02 01:35:33|Twitter for Android|140|RT @AfricaFactsZo...|Mikel John Obi is...|    0| 949|                null|   Africa Facts Zone|     AfricaFactsZone|          Elvis Good|    Anambra, Nigeria|      142|    336|
# |1013597005967437825|  en|2018-07-02 01:35:32|       Twitter Lite| 98|RT @onxmyown: Pow...|            Poweeeer|    0|   4|PowerByEXO,WorldC...|Paola,FIFA World ...|onxmyown,FIFAWorl...|             Andrea?|    en tu corazón :v|      152|    251|
# |1013597004231008257|  en|2018-07-02 01:35:32| Twitter for iPhone|129|RT @marinamaral2:...|Soccer team of Br...|    0| 373|    WorldCup,history|       Marina Amaral|        marinamaral2|telha de amianto ...|www.behance.net/9...|      333|    439|
# |1013596996794343424|  en|2018-07-02 01:35:30|Twitter for Android|140|RT @UtdIndonesia:...|It not the day Da...|    0|   5|                null|United Indonesia,...|UtdIndonesia,d_de...|       Yahya Hidayat|Varia Agung, Lampung|      350|    323|
# |1013596995305472000|  en|2018-07-02 01:35:30|Twitter for Android|140|RT @EmbassyofRuss...|proceeds to the f...|    0| 165|Russia,Spain,Worl...|    Russia in RSA ??|     EmbassyofRussia|                ????|     ???????, ??????|      343|    666|
# |1013596986614820865|  en|2018-07-02 01:35:27|Twitter for Android|135|RT @_anujsinghal:...|The best world cu...|    0|   8|        RUS,WorldCup|        Anuj Singhal|        _anujsinghal|                 Ram|                null|        4|    110|
# |1013596981619458048|  en|2018-07-02 01:35:26|       Twitter Lite|110|RT @onxmyown: I S...|       SAY X YOU SAY|    0|   4|PowerByEXO,WorldC...|Paola,FIFA World ...|onxmyown,FIFAWorl...|             Andrea?|    en tu corazón :v|      152|    251|
# |1013596980159926272|  en|2018-07-02 01:35:26|   Twitter for iPad|166|Get the best in s...|Get the best in s...|    0|   0|sportstalk,sports...|                null|                null|        Michael Bari|                null|     1507|   1158|
# |1013596954025123840|  en|2018-07-02 01:35:20|       Twitter Lite|128|RT @UtdIndonesia:...|Congrats Paul Pog...|    0|  90|            worldcup|    United Indonesia|        UtdIndonesia|                 aca|pabuaran cibinong...|      286|    181|
# |1013596951504355330|  en|2018-07-02 01:35:19| Twitter Web Client|140|RT @ferdimutlu16:...|Follow me everyon...|    0|  23|airdrop,bitcoin,I...|          Gezbabagez|        ferdimutlu16|            TR4SHGOD| North Carolina, USA|     2496|   3327|
# +-------------------+----+-------------------+-------------------+---+--------------------+--------------------+-----+----+--------------------+--------------------+--------------------+--------------------+--------------------+---------+-------+
# only showing top 20 rows

# %%
# Check number of partitions
print(fifa.rdd.getNumPartitions())
# Out:
# 8

# %%
# Repartition
fifa = fifa.orderBy('Date').repartition(20).persist()
print(fifa.rdd.getNumPartitions())
# print(fifa.rdd.glom().collect())
# Out:
# 20

# %%
# Save newly partitioned data to FileStore
dbutils.fs.rm("FileStore/tables/fifaTime/", True)
fifa.write.format("csv").option("header", True).save("FileStore/tables/fifaTime/")

# %%
# Static Windows sanity check
fifa = fifa.select(f.col('ID'), f.col('Date'), f.col('Hashtags')).filter(f.col('Hashtags').isNotNull()).persist()
fifa = fifa.withColumn('Hashtags', f.explode(f.split('Hashtags', ','))).persist()
fifaWin = fifa.groupBy(f.window("Date", "60 minutes", "30 minutes"), "HashTags").agg(f.count("ID").alias("count")).filter(f.col("count") > 100).orderBy(f.col("window").asc(), f.col("count").desc())

# %%
# Check output 
fifaWin.show(20, False)
# Out:
# +------------------------------------------+-------------+-----+
# |window                                    |HashTags     |count|
# +------------------------------------------+-------------+-----+
# |{2018-06-29 23:00:00, 2018-06-30 00:00:00}|WorldCup     |152  |
# |{2018-06-29 23:30:00, 2018-06-30 00:30:00}|WorldCup     |1270 |
# |{2018-06-29 23:30:00, 2018-06-30 00:30:00}|FIFAStadiumDJ|615  |
# |{2018-06-30 00:00:00, 2018-06-30 01:00:00}|WorldCup     |2278 |
# |{2018-06-30 00:00:00, 2018-06-30 01:00:00}|FIFAStadiumDJ|1073 |
# |{2018-06-30 00:00:00, 2018-06-30 01:00:00}|EXO          |157  |
# |{2018-06-30 00:00:00, 2018-06-30 01:00:00}|worldcup     |144  |
# |{2018-06-30 00:30:00, 2018-06-30 01:30:00}|WorldCup     |2158 |
# |{2018-06-30 00:30:00, 2018-06-30 01:30:00}|FIFAStadiumDJ|990  |
# |{2018-06-30 00:30:00, 2018-06-30 01:30:00}|EXO          |156  |
# |{2018-06-30 00:30:00, 2018-06-30 01:30:00}|worldcup     |150  |
# |{2018-06-30 01:00:00, 2018-06-30 02:00:00}|WorldCup     |1884 |
# |{2018-06-30 01:00:00, 2018-06-30 02:00:00}|FIFAStadiumDJ|861  |
# |{2018-06-30 01:00:00, 2018-06-30 02:00:00}|EXO          |217  |
# |{2018-06-30 01:30:00, 2018-06-30 02:30:00}|WorldCup     |886  |
# |{2018-06-30 01:30:00, 2018-06-30 02:30:00}|FIFAStadiumDJ|398  |
# |{2018-06-30 01:30:00, 2018-06-30 02:30:00}|EXO          |135  |
# |{2018-06-30 15:30:00, 2018-06-30 16:30:00}|WorldCup     |5487 |
# |{2018-06-30 15:30:00, 2018-06-30 16:30:00}|FRAARG       |1748 |
# |{2018-06-30 15:30:00, 2018-06-30 16:30:00}|FRA          |1626 |
# +------------------------------------------+-------------+-----+
# only showing top 20 rows

# %%
# Structured Streaming 
sourceStream = spark.readStream.format("csv").option("header", True).schema(fifaSchema).option("maxFilesPerTrigger", 1).load("dbfs:///FileStore/tables/fifaTime/")

# %%
# Query for streaming information
fifaWin = sourceStream.withWatermark("Date", "24 hours")\
                      .select(f.col('ID'), f.col('Date'), f.col('Hashtags'))\
                      .filter(f.col('Hashtags').isNotNull())\
                      .withColumn('Hashtags', f.explode(f.split('Hashtags', ',')))\
                      .groupBy(f.window("Date", "60 minutes", "30 minutes"), "HashTags")\
                      .agg(f.count("ID").alias("count"))\
                      .filter(f.col("count") > 100)\
                      .orderBy(f.col("window").asc(), f.col("count").desc())

# %%
# Set up the sink
sinkStream = fifaWin.writeStream.outputMode("complete").format("memory").queryName("fifWin").trigger(processingTime='10 seconds'). start()

# %%
# Check the output while stream happening
spark.sql("SELECT * FROM fifWin").show(20, False)
# Out:
# +------------------------------------------+-------------+-----+
# |window                                    |HashTags     |count|
# +------------------------------------------+-------------+-----+
# |{2018-06-29 23:00:00, 2018-06-30 00:00:00}|WorldCup     |152  |
# |{2018-06-29 23:30:00, 2018-06-30 00:30:00}|WorldCup     |1270 |
# |{2018-06-29 23:30:00, 2018-06-30 00:30:00}|FIFAStadiumDJ|615  |
# |{2018-06-30 00:00:00, 2018-06-30 01:00:00}|WorldCup     |2278 |
# |{2018-06-30 00:00:00, 2018-06-30 01:00:00}|FIFAStadiumDJ|1073 |
# |{2018-06-30 00:00:00, 2018-06-30 01:00:00}|EXO          |157  |
# |{2018-06-30 00:00:00, 2018-06-30 01:00:00}|worldcup     |144  |
# |{2018-06-30 00:30:00, 2018-06-30 01:30:00}|WorldCup     |2158 |
# |{2018-06-30 00:30:00, 2018-06-30 01:30:00}|FIFAStadiumDJ|990  |
# |{2018-06-30 00:30:00, 2018-06-30 01:30:00}|EXO          |156  |
# |{2018-06-30 00:30:00, 2018-06-30 01:30:00}|worldcup     |150  |
# |{2018-06-30 01:00:00, 2018-06-30 02:00:00}|WorldCup     |1884 |
# |{2018-06-30 01:00:00, 2018-06-30 02:00:00}|FIFAStadiumDJ|861  |
# |{2018-06-30 01:00:00, 2018-06-30 02:00:00}|EXO          |217  |
# |{2018-06-30 01:30:00, 2018-06-30 02:30:00}|WorldCup     |886  |
# |{2018-06-30 01:30:00, 2018-06-30 02:30:00}|FIFAStadiumDJ|398  |
# |{2018-06-30 01:30:00, 2018-06-30 02:30:00}|EXO          |135  |
# |{2018-06-30 15:30:00, 2018-06-30 16:30:00}|WorldCup     |5487 |
# |{2018-06-30 15:30:00, 2018-06-30 16:30:00}|FRAARG       |1748 |
# |{2018-06-30 15:30:00, 2018-06-30 16:30:00}|FRA          |1626 |
# +------------------------------------------+-------------+-----+
# only showing top 20 rows
